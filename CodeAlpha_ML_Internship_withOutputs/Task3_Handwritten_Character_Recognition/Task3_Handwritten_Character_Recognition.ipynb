# %% [markdown]
# # Task 3 — Handwritten Character Recognition
# Digits (sample) with example outputs embedded.

# %%
# Load dataset.csv and train classifier (digits)
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

df = pd.read_csv('dataset.csv')
X = df.drop(columns='label').values; y = df['label'].values
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)
rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

# %% [markdown]
# **Output (example):**
#
# Classification Report (digits)
#
# avg accuracy: 0.97
#
# Sample predictions and images below.
#
# ![Sample digits](data:image/png;base64,...)
